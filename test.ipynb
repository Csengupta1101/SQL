# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel(r"C:\Workflow\All Table Structure\all_tables.xlsx")

# %%
df.head()
# Out:
#     Identity_tbl   Referred_By_tbl               aa   ac_data
# 0    identity_id    Referred_By_id        dealer_id        id  \
# 1  identity_name  Referred_By_Name          ship_id   ac_name
# 2            NaN         is_active      dealer_type  ac_phone
# 3            NaN               NaN  account_type_id   ac_type
# 4            NaN               NaN      dealer_name  state_id
#
#   account_business_details account_business_followup_details
# 0              business_id              business_followup_id  \
# 1               sub_cat_id                       question_id
# 2                 brand_id                        answers_id
# 3      competitor_brand_id                            emp_id
# 4                 avg_sale                         dealer_id
#
#   account_delete_req_transaction account_delete_request_tbl
# 0                 ddreq_trans_id                 request_id  \
# 1                     request_id                     emp_id
# ...

# %%
common_word = "dashboard"
filtered_columns = df.filter(like = common_word)
lst = []

for i in filtered_columns.columns:
    lst.append(i)
print(lst)
# Out:
# ['dashboard_cal_temp', 'dashboard_data1', 'dashboard_state', 'dealer_target_vs_achvmnt_dashboard', 'emp_visit_dashboard', 'inactive_dealers_dashboard', 'lead_generated_dashboard', 'open_leads_dashboard', 'primary_dashboard', 'primary_lifting_dashboard_data', 'secondary_dashboard', 'secondary_lifting_dashboard_data', 'tablue_meet_dashboard', 'tbl_meet_dashboard', 'tbl_secondary_sale_dashboard', 'tbl_unique_bill_dashboard', 'tbl_visit_dashboard']

# %%
df1 = pd.read_excel(r"C:\Workflow\All Table Structure\Table_Structures.xlsx")

# %%
df1.columns
# Out:
# Index(['employee_tbl', 'dealerhistory', 'account_priority_geotag_transactions',
#        'dealer_checkin_checkout', 'dealer_checkin_checkout_dt',
#        'dispatch_item', 'dealer_partner_fn', 'dealer_master',
#        'tbl_live_km_tracking', 'recomend_project_approval_details_tbl',
#        'recomend_project_tbl', 'recomend_project_details_tbl',
#        'rec_project_account_tbl', 'block_tbl', 'dealer_district',
#        'district_tbl', 'order_prod_tbl',
#        'distributer_working_as_dealer_for_dlppt_tbl', 'order_tbl',
#        'subDealerPurchase_tbl', 'subdealer_order_prod_tbl',
#        'subdealer_order_tbl', 'profile_tbl', 'user_tbl', 'account_type_tbl',
#        'recProjectReferredBy', 'attendance_tbl', 'state_tbl'],
#       dtype='object')
